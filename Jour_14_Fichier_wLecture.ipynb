# %%
resultat = "Mutation identifiée sur le gène TP53"

#J'écrit dans le fichier texte rapport, grace à la fonction "w" différent de "r", j'écrit à l'intérieure le contenu de resultat, plus la date du jour
with open("rapport.txt", "w") as f:
    f.write(resultat + "\n")
    f.write("Analyse terminée le 02/02/2026")

print("Le rapport est bon.")
# Out:
# Le rapport est bon.
