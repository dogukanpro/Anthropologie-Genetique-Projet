# %%
adn = "ATGCGTACGT"

# %% [markdown]
# Extraction du premier codon

# %%
debut = adn[:3]

# %% [markdown]
# Extraction de la séquence allant de l'index 2 à l'index 6

# %%
milieu = adn[2:6]

# %% [markdown]
# Extractio des 4 dernières

# %%
fin = adn[-4:]

# %% [markdown]
# Affichage

# %%
print(debut)
print(milieu)
print(fin)
# Out:
# ATG
# GCGT
# ACGT
