# %% [markdown]
# Initialisation : Voici une bibliothèque, avec une information qu'on veut supprimer, et une autre mdodifier son contenu

# %%
echantillon = {"Chasseur_Cueilleur": "Ok", "Groupe_Indetermine": "?", "Fermier_Neolithique": "Inconnu"}

# %% [markdown]
# Exécution

# %%
del echantillon["Groupe_Indetermine"]
echantillon["Fermier_Neolithique"] = "Ok"

# %% [markdown]
# Affichage

# %%
print(echantillon)
# Out:
# {'Chasseur_Cueilleur': 'Ok', 'Fermier_Neolithique': 'Ok'}
