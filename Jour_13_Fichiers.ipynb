# %%
try:
    with open("sequence.txt", "r") as f:
        donnees = f.read()
except KeyError:
    print("Erreur !")

# %%
print(f"Voici la longueur de la séquence ADN, stocké dans le fichier séquence : {len(donnees)}")
# Out:
# Voici la longueur de la séquence ADN, stocké dans le fichier séquence : 11
