# %%
gene = "TP53"
longueur = 1172
taux_gc = 41.5

print (f"Le gène {gene} fait {longueur} paires de bases.")

espece = "humain"
structure_cellulaire = "bicouche lipidique"
nb_cellules_estimes = 30000000000000

print(f"L'espece {espece} est composée d'environ {nb_cellules_estimes} de cellules.")
print(f"Chaque cellule est protégée par une {structure_cellulaire}.")
# Out:
# Le gène TP53 fait 1172 paires de bases.
# L'espece humain est composée d'environ 30000000000000 de cellules.
# Chaque cellule est protégée par une bicouche lipidique.
