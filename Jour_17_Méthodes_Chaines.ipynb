# %% [markdown]
# Initialisation des données en format csv

# %%
donnees_brutes = "A,T,C,G,G,A"

# %% [markdown]
# Affichage + Séparation des données à chaque virgule reperé, puis ça continu en les coller avec du vide pour créer une séquence continu

# %%
liste_bases = donnees_brutes.split(",")
liste_bases.append("G")
resultat_finale = "".join(liste_bases)

print(f"Lorsque la liste est separé:"{liste_bases})
print(resultat_finale)
# Out:
# ['A', 'T', 'C', 'G', 'G', 'A', 'G']
# ATCGGAG
