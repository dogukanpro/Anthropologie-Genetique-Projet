# %%
echantillons = ["ATGC", "ATGCPTA", "GGC", "ATTCGGT", "A"]

# %%
On va extraitre uniquement les sequence plus long que 5

# %%
valides = [s for s in echantillons if len(s) > 5]

# %%
Affichage

# %%
print(valides)
# Out:
# ['ATGCPTA', 'ATTCGGT']
