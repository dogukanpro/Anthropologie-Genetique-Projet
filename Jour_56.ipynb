# %% [markdown]
# Sujet du jour : Matrices (listes dans une autre liste)

# %%
distances = [
    [0.0, 0.05, 0.12],
    [0.05, 0.0, 0.08],
    [0.12, 0.08, 0.0]
]

# %%
dist_ibere_ligure = distances[1][2]

# %% [markdown]
# Affichage

# %%
print(f"Distance génétique Ibères/Ligures : {dist_ibere_ligure}")
print("\nTableau complet des distances")
for ligne in distances:
    print(ligne)
# Out:
# Distance génétique Ibères/Ligures : 0.08
#
# Tableau complet des distances
# [0.0, 0.05, 0.12]
# [0.05, 0.0, 0.08]
# [0.12, 0.08, 0.0]
