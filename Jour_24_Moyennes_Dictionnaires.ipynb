# %%
population_alleles = {"Allele_A (Bleu)": 45, "Allele_B (Vert)": 30, "Allele_C (Rouge)": 25}
somme_totale = 0

# %%
for quantite in population_alleles.values() :
    somme_totale += quantite

# %%
moyenne = somme_totale / len(groupe)
print(f"Nombre total d'allèles vues : {somme_totale}")
print(f"En moyenne, chaque type d'allèle est présent {moyenne} fois.")
# Out:
# Nombre total d'allèles vues : 100
# En moyenne, chaque type d'allèle est présent 25.0 fois.
