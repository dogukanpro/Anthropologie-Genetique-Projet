# %%
import math

# %%
frequence_caractere = 0.09

# %% [markdown]
# Calcul racine carrée

# %%
q = math.sqrt(frequence_caractere)

# %% [markdown]
# Affichage + verification pour voir que je retombe bien sur 0,09

# %%
verif = math.pow(q, 2)

print(q)
print(verif)
# Out:
# 0.3
# 0.09
