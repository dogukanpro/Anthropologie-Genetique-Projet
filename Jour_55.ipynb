# %% [markdown]
# Sujet : La fonction enumerate ()

# %%
sequence = "ATCGCCGAT"

print("Recherche Cytosines (C)")

for pos, base in enumerate(sequence):
    if base == "C":
        print(f"Cytosine trouvée à la position : {pos + 1}")
