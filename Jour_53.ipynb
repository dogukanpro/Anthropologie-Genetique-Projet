# %% [markdown]
# Révision : programmation orientée objet

# %%
class Individu:
    def __init__(self, nom_recu, peuple_recu, adn_recu):
        self.nom = nom_recu
        self.peuple = peuple_recu
        self.adn = adn_recu

# %%
echantillon_1 = Individu("Anatolien", "Chasseur-Cueilleur", "ATGCG...")
echantillon_2 = Individu("Basque", "Celte", "TTAGC...")

# %%
print(f"Analyse de l'échantillon : {echantillon_1.nom}")
print(f"Origine : {echantillon_1.peuple}")
