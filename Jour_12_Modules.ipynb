# %% [markdown]
# Importation du module random

# %%
import random

# %% [markdown]
# Initialisation

# %%
bases = ["A", "T", "G", "C"]
choix = random.choice(bases)
erreur =random.randint(1, 10)

# %% [markdown]
# Affichage de la mutation choisie aléatoirement grace à la fonction random choice + simulation d'un erreur de réplication grace à random randint qui nous permet de tirer un nombree aléatoire entre un nombre x et un autre nombre x1 (ici 1 et 10)

# %%
print(f"Mutation détectée : la nouvelle base est {choix}")
print(f"{erreur} erreurs trouvées durant la mitose")
# Out:
# Mutation détectée : la nouvelle base est A
# 4 erreurs trouvées durant la mitose
